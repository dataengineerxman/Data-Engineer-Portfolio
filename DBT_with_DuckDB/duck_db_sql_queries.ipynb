# %% [markdown]
# Connect to DuckDB & Run Queries

# %%
import duckdb
import pandas as pd

# %%
sql_query = "SELECT 1 AS test_column"

# %%
with duckdb.connect("data/nyc_parking_violations.db") as conn:
    conn.execute("SELECT 1")
